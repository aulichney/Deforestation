# %%
import pandas as pd
import pyreadr
import numpy as np
from tqdm import tqdm

# %%
path = '/Users/annieulichney/Library/CloudStorage/Box-Box/Deforestation_MachineLearning/Data/cand_prefeito.Rdata'
pathvote = '/Users/annieulichney/Library/CloudStorage/Box-Box/Deforestation_MachineLearning/Data/cand_prefeito_vote.Rdata'

df = pyreadr.read_r(path)['cand']
vote = pyreadr.read_r(pathvote)['cand']

# %%
#for each mun and each year want winning candidate, bio info, margin etc, 

#votes, total votes, pct votes, political party, incumbent runs, incumbent wins, seat limit

# %%
vote.head()
# Out:
#     ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 0  1996      1  eleicao ordinaria       AL      2704302            27855
# 1  1996      1  eleicao ordinaria       AM      1302603             2550
# 2  1996      1  eleicao ordinaria       BA      2927408            38490
# 3  1996      1  eleicao ordinaria       BA      2927408            38490
# 4  1996      1  eleicao ordinaria       BA      2927408            38490
#
#       cargo sigla_partido numero_candidato sequencial_candidato  \
# 0  prefeito           PSD               41                  NaN
# 1  prefeito          PSTU               16                  NaN
# 2  prefeito           PAN               26                  NaN
# 3  prefeito           PCO               29                  NaN
# 4  prefeito           PGT               30                  NaN
#
#   id_candidato_bd   resultado  votos
# 0             NaN  nao eleito   2388
# 1             NaN  nao eleito   1713
# 2             NaN  nao eleito  15721
# 3             NaN  nao eleito    705
# 4             NaN  nao eleito    989

# %%
keep = vote[vote.resultado == 'eleito'][['ano', 'id_municipio', 'id_candidato_bd', 'sigla_partido' ,'votos']]
keep.columns = ['ano', 'id_municipio', 'id_candidato_bd', 'sigla_partido', 'votos_winner']

#total votes for that municipio that year
keep = pd.merge(keep, vote[['ano', 'id_municipio', 'votos']].groupby(['ano', 'id_municipio']).agg('sum').reset_index(), how = 'left', left_on = ['ano', 'id_municipio'], right_on = ['ano', 'id_municipio'])
keep.head()
# Out:
#     ano id_municipio id_candidato_bd sigla_partido  votos_winner  votos
# 0  2000      2708907         1265591           PSD          3147   4882
# 1  2000      1302553           19147           PST          1455   5658
# 2  2000      2903300         1071793           PAN          2135   3598
# 3  2000      2906907          962907           PSD          4614   8760
# 4  2000      2908606         1523132           PST          3643   8872

# %%
keep['incumbant_run'] = np.zeros(keep.shape[0])
keep['incumbant_win'] = np.zeros(keep.shape[0])
keep['term_lim_seat'] = np.zeros(keep.shape[0])
keep['margin'] = np.zeros(keep.shape[0])

# %%
#first find does incumbant run and does incumbant win? 
missing_incumbant = []

for i in tqdm(range(vote.shape[0])):
    row = vote.iloc[i]
    row

    #did they win? 
    if row.resultado == 'eleito':
        #check 4 years from current year for year+4 and id match
        incumbant_run = vote[(vote.ano == row.ano + 4) & (vote.id_candidato_bd == row.id_candidato_bd) & (vote.id_municipio == row.id_municipio)].shape[0]
        
       
        #if they run in 4 years, check if they win 
        if incumbant_run == 1:
            if vote[(vote.ano == row.ano + 4) & (vote.id_candidato_bd == row.id_candidato_bd)].shape[0] == 0:
                print('Missing data with :' + str(i))

            else:
                incumbant_win = int(vote[(vote.ano == row.ano + 4) & (vote.id_candidato_bd == row.id_candidato_bd)].resultado == 'eleito')
        
        
        #if they do not run in 4 years, win is 0
        if incumbant_run==0:
            incumbant_win = 0
        
        #stop if year is 2020 because 2024 not in dataset
        if row.ano == 2020:
            continue
        
        #update incumbent run and incumbent win for each row
        if keep[(keep.ano == row.ano+4)&(keep.id_municipio == row.id_municipio)].shape[0] == 0:
            #print('Missing row at :' + str(i) + 'year = ' + str(row.ano+4) + ' munic = ' + str(row.id_municipio))
            missing_incumbant.append([i, row.ano+4,row.id_municipio])
        else:
            keep.loc[keep[(keep.ano == row.ano+4)&(keep.id_municipio == row.id_municipio)].index[0], 'incumbant_run'] = incumbant_run
            keep.loc[keep[(keep.ano == row.ano+4)&(keep.id_municipio == row.id_municipio)].index[0], 'incumbant_win'] = incumbant_win
# Out:
# 100%|██████████| 96838/96838 [13:59<00:00, 115.34it/s]

# %%
vote[(vote.ano == row.ano + 4) & (vote.id_candidato_bd == row.id_candidato_bd) & (vote.id_municipio == row.id_municipio)]
# Out:
#        ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 4974  2008      1  eleicao ordinaria       BA      2903409            33677
#
#          cargo sigla_partido numero_candidato sequencial_candidato  \
# 4974  prefeito            PP               11                20971
#
#      id_candidato_bd resultado  votos
# 4974         1386484    eleito   5778

# %%
i = 658
row = vote.iloc[i]
row
# Out:
# ano                                  2004
# turno                                   1
# tipo_eleicao            eleicao ordinaria
# sigla_uf                               MA
# id_municipio                      2109700
# id_municipio_tse                     8931
# cargo                            prefeito
# sigla_partido                         PAN
# numero_candidato                       26
# sequencial_candidato                   11
# id_candidato_bd                   1637914
# resultado                      nao eleito
# votos                                1074
# Name: 658, dtype: object

# %%
temp_frame = vote[(vote.id_candidato_bd == row.id_candidato_bd)&(vote.resultado == 'eleito')]
temp_frame = temp_frame.sort_values('ano').reset_index()
temp_frame
# Out:
#    index   ano  turno       tipo_eleicao sigla_uf id_municipio  \
# 0  36804  2004      1  eleicao ordinaria       BA      2903409
# 1   4974  2008      1  eleicao ordinaria       BA      2903409
#
#   id_municipio_tse     cargo sigla_partido numero_candidato  \
# 0            33677  prefeito          PMDB               15
# 1            33677  prefeito            PP               11
#
#   sequencial_candidato id_candidato_bd resultado  votos
# 0                   44         1386484    eleito   5552
# 1                20971         1386484    eleito   5778

# %%
for index, row2 in temp_frame.iterrows():
        if temp_frame[temp_frame.ano == row2.ano + 4 ].shape[0] != 0:
            
            if keep[(keep.ano == row2.ano + 8) & (keep.id_municipio == row2.id_municipio)].shape[0] == 0:
                missing.append([i,row2.ano + 8,row2.id_municipio])
                #missing.append('Missing at ' + str(i) + ' year = ' + str(row.ano) + str(' munic = ') + str(row.id_municipio))
                                 
            else:
                print(row2.ano + 8)
                #keep.loc[keep[(keep.ano == row2.ano + 8) & (keep.id_municipio == row2.id_municipio)].index[0], 'term_lim_seat'] = 1
# Out:
# 2012

# %%
keep[(keep.ano == row2.ano + 8) & (keep.id_municipio == row2.id_municipio)]
# Out:
#         ano id_municipio id_candidato_bd sigla_partido  votos_winner  votos  \
# 16992  2016      2903409         1331685          PODE          4896  12114
#
#        incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct
# 16992            1.0            0.0            0.0   503.0    0.40416

# %%
#now do if the seat is term limited: 
missing = []

for i in tqdm(range(vote.shape[0])):
    row = vote.iloc[i]
    
    temp_frame = vote[(vote.id_candidato_bd == row.id_candidato_bd)&(vote.resultado == 'eleito')]
    temp_frame = temp_frame.sort_values('ano').reset_index()
    
    for index, row2 in temp_frame.iterrows():
        if temp_frame[temp_frame.ano == row2.ano+4].shape[0] != 0:
            
            if keep[(keep.ano == row2.ano + 8) & (keep.id_municipio == row2.id_municipio)].shape[0] == 0:
                missing.append([i,row2.ano+8,row2.id_municipio])
                #missing.append('Missing at ' + str(i) + ' year = ' + str(row.ano) + str(' munic = ') + str(row.id_municipio))
                                 
            else:
                keep.loc[keep[(keep.ano == row2.ano + 8) & (keep.id_municipio == row2.id_municipio)].index[0], 'term_lim_seat'] = 1
# Out:
# 100%|██████████| 96838/96838 [22:34<00:00, 71.51it/s]

# %%
#now get margin of victory


vote_missing = []
for i in tqdm(range(keep.shape[0])):
    row = keep.iloc[i]
    
    if vote[(vote.ano == row.ano) & (vote.id_municipio == row.id_municipio)].shape[0] == 0:
        vote_missing.append(i, row.ano, row.id_municipio)
    else:
        vote_sort = sorted(vote[(vote.ano == row.ano) & (vote.id_municipio == row.id_municipio)].votos, reverse = True)
        vote_sort.append(0)
        margin = vote_sort[0] - vote_sort[1]
        
    if keep[(keep.ano == row.ano) & (keep.id_municipio == row.id_municipio)].shape[0] != 0:
        keep.loc[keep[(keep.ano == row.ano) & (keep.id_municipio == row.id_municipio)].index[0], 'margin'] = margin
# Out:
# 100%|██████████| 33756/33756 [10:02<00:00, 56.02it/s]

# %%
keep['votos_pct'] = keep.votos_winner/keep.votos

# %%
vote[vote.id_candidato_bd == '1386484'].sort_values('ano')
# Out:
#         ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 31293  2000      1  eleicao ordinaria       BA      2903409            33677
# 36804  2004      1  eleicao ordinaria       BA      2903409            33677
# 4974   2008      1  eleicao ordinaria       BA      2903409            33677
# 7458   2016      1  eleicao ordinaria       BA      2903409            33677
# 92059  2020      1  eleicao ordinaria       BA      2903409            33677
#
#           cargo sigla_partido numero_candidato sequencial_candidato  \
# 31293  prefeito          PMDB               15                  NaN
# 36804  prefeito          PMDB               15                   44
# 4974   prefeito            PP               11                20971
# 7458   prefeito            PP               11          50000006487
# 92059  prefeito           PSD               55          50000993073
#
#       id_candidato_bd   resultado  votos
# 31293         1386484  nao eleito   3497
# 36804         1386484      eleito   5552
# 4974          1386484      eleito   5778
# 7458          1386484  nao eleito   4393
# 92059         1386484  nao eleito   5144

# %%
vote[vote.id_municipio == 2903409]

# %%
keep[keep.id_municipio == '2903409']
# Out:
#         ano id_municipio id_candidato_bd sigla_partido  votos_winner  votos  \
# 658    2000      2903409         1331685           PPB          6012   9509
# 1298   2008      2903409         1386484            PP          5778  10706
# 2915   2012      2903409         1620932            PP          4743  11247
# 3428   2020      2903409         1588357            PP          7034  12256
# 12822  2004      2903409         1386484          PMDB          5552  10126
# 16992  2016      2903409         1331685          PODE          4896  12114
#
#        incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct
# 658              0.0            0.0            0.0  2515.0   0.632243
# 1298             1.0            1.0            1.0   850.0   0.539697
# 2915             0.0            0.0            1.0   404.0   0.421712
# 3428             0.0            0.0            0.0  1890.0   0.573923
# 12822            0.0            0.0            0.0   978.0   0.548292
# 16992            1.0            0.0            0.0   503.0   0.404160

# %%
vote[vote.id_municipio == '2903409'].sort_values('ano')
# Out:
#         ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 3530   2000      1  eleicao ordinaria       BA      2903409            33677
# 31293  2000      1  eleicao ordinaria       BA      2903409            33677
# 36804  2004      1  eleicao ordinaria       BA      2903409            33677
# 51364  2004      1  eleicao ordinaria       BA      2903409            33677
# 4974   2008      1  eleicao ordinaria       BA      2903409            33677
# 76473  2008      1  eleicao ordinaria       BA      2903409            33677
# 8625   2012      1  eleicao ordinaria       BA      2903409            33677
# 41732  2012      1  eleicao ordinaria       BA      2903409            33677
# 76839  2012      1  eleicao ordinaria       BA      2903409            33677
# 7458   2016      1  eleicao ordinaria       BA      2903409            33677
# 47262  2016      1  eleicao ordinaria       BA      2903409            33677
# 71558  2016      1  eleicao ordinaria       BA      2903409            33677
# 9754   2020      1  eleicao ordinaria       BA      2903409            33677
# 46404  2020      1  eleicao ordinaria       BA      2903409            33677
# 92059  2020      1  eleicao ordinaria       BA      2903409            33677
#
#           cargo sigla_partido numero_candidato sequencial_candidato  \
# 3530   prefeito           PPB               11                  NaN
# 31293  prefeito          PMDB               15                  NaN
# 36804  prefeito          PMDB               15                   44
# 51364  prefeito            PL               22                    2
# 4974   prefeito            PP               11                20971
# 76473  prefeito           PRP               44                23165
# 8625   prefeito            PP               11          50000017354
# 41732  prefeito          PMDB               15          50000035727
# 76839  prefeito           PRP               44          50000021420
# 7458   prefeito            PP               11          50000006487
# 47262  prefeito          PODE               19          50000031821
# 71558  prefeito           PSB               40          50000003133
# 9754   prefeito            PP               11          50000769350
# 46404  prefeito           PSL               17          50000770485
# 92059  prefeito           PSD               55          50000993073
#
#       id_candidato_bd   resultado  votos
# 3530          1331685      eleito   6012
# 31293         1386484  nao eleito   3497
# 36804         1386484      eleito   5552
# 51364          840214  nao eleito   4574
# 4974          1386484      eleito   5778
# 76473         1223898  nao eleito   4928
# 8625          1620932      eleito   4743
# 41732         1588357  nao eleito   2165
# 76839         1223898  nao eleito   4339
# 7458          1386484  nao eleito   4393
# 47262         1331685      eleito   4896
# 71558         1620932  nao eleito   2825
# 9754          1588357      eleito   7034
# 46404          726217  nao eleito     78
# 92059         1386484  nao eleito   5144

# %%
keep[(keep.id_candidato_bd == '1386484')]
# Out:
#         ano id_municipio id_candidato_bd sigla_partido  votos_winner  votos  \
# 1298   2008      2903409         1386484            PP          5778  10706
# 12822  2004      2903409         1386484          PMDB          5552  10126
#
#        incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct
# 1298             1.0            1.0            1.0   850.0   0.539697
# 12822            0.0            0.0            0.0   978.0   0.548292

# %%
keep[(keep.incumbant_run == 1) & (keep.term_lim_seat == 1)]
# Out:
#         ano id_municipio id_candidato_bd  sigla_partido  votos_winner  votos  \
# 1298   2008      2903409         1386484             PP          5778  10706
# 1523   2008      4114203          391777             PP          9697  20469
# 1564   2008      2402402         1659301             PP          2665   5049
# 1579   2008      1100304          406494             PP         18944  35301
# 1704   2008      4320354         1235889             PP          2199   3599
# ...     ...          ...             ...            ...           ...    ...
# 32380  2012      2805802          883113            PSD          6815  12609
# 32458  2020      1301159         1216968            PSD          5202  12937
# 33573  2020      2302404          291889  SOLIDARIEDADE         19507  31955
# 33727  2020      3129905          853340           PROS          2016   2016
# 33734  2020      5106455          667314           PROS          1102   2163
#
#        incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct
# 1298             1.0            1.0            1.0   850.0   0.539697
# 1523             1.0            0.0            1.0  1282.0   0.473741
# 1564             1.0            0.0            1.0   418.0   0.527827
# 1579             1.0            0.0            1.0  4102.0   0.536642
# 1704             1.0            0.0            1.0   799.0   0.611003
# ...              ...            ...            ...     ...        ...
# 32380            1.0            1.0            1.0  1021.0   0.540487
# 32458            1.0            1.0            1.0   927.0   0.402102
# 33573            1.0            0.0            1.0  7579.0   0.610452
# 33727            1.0            1.0            1.0  2016.0   1.000000
# 33734            1.0            0.0            1.0    41.0   0.509478
#
# [102 rows x 11 columns]

# %%
keep[(keep.ano == row2.ano + 8) & (keep.id_municipio == row2.id_municipio)]
# Out:
#         ano id_municipio id_candidato_bd sigla_partido  votos_winner  votos  \
# 16992  2016      2903409         1331685          PODE          4896  12114
#
#        incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct
# 16992            1.0            0.0            0.0   503.0    0.40416

# %%
pd.merge(keep, df[['id_candidato_bd', 'genero', 'ocupacao', 'instrucao', 'ano', 'idade']], how = 'left', left_on = ['id_candidato_bd', 'ano'], right_on = ['id_candidato_bd', 'ano'])
# Out:
#          ano id_municipio id_candidato_bd sigla_partido  votos_winner   votos  \
# 0       2000      2708907         1265591           PSD          3147    4882
# 1       2000      1302553           19147           PST          1455    5658
# 2       2000      2903300         1071793           PAN          2135    3598
# 3       2000      2906907          962907           PSD          4614    8760
# 4       2000      2908606         1523132           PST          3643    8872
# ...      ...          ...             ...           ...           ...     ...
# 125486  2020      1101807          932364          PROS          2484    4470
# 125487  2020      3502754         1706236          PROS          5124   12397
# 125488  2020      1704105         1659020          PROS           635    1624
# 125489  2020      1709500         1719990          PROS         20116   39404
# 125490  2020      2303709          441082          PROS         83588  332862
#
#         incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct  \
# 0                 0.0            0.0            0.0  1412.0   0.644613
# 1                 0.0            0.0            0.0   155.0   0.257158
# 2                 0.0            0.0            0.0   708.0   0.593385
# 3                 0.0            0.0            0.0   640.0   0.526712
# 4                 0.0            0.0            0.0  1015.0   0.410618
# ...               ...            ...            ...     ...        ...
# 125486            0.0            0.0            0.0   498.0   0.555705
# 125487            1.0            0.0            0.0  2788.0   0.413326
# 125488            0.0            0.0            1.0    35.0   0.391010
# 125489            0.0            0.0            1.0  3057.0   0.510507
# 125490            2.0            0.0            0.0  3543.0   0.251119
#
#            genero                                   ocupacao  \
# 0       masculino  proprietario de estabelecimento comercial
# 1       masculino                                     medico
# 2       masculino                                     outros
# 3       masculino                                     outros
# 4       masculino  proprietario de estabelecimento comercial
# ...           ...                                        ...
# 125486   feminino                  servidor publico estadual
# 125487  masculino                                 engenheiro
# 125488  masculino                                 empresario
# 125489   feminino                 servidor publico municipal
# 125490  masculino                       jornalista e redator
#
#                             instrucao idade
# 0               ensino medio completo    45
# 1            ensino superior completo    31
# 2            ensino superior completo    51
# 3       ensino fundamental incompleto    58
# 4         ensino fundamental completo    42
# ...                               ...   ...
# 125486       ensino superior completo    41
# 125487       ensino superior completo    41
# 125488    ensino fundamental completo    61
# 125489       ensino superior completo    58
# 125490          ensino medio completo    42
#
# [125491 rows x 15 columns]

# %%
#pd.merge(keep, vote[['ano', 'id_municipio', 'votos']].groupby(['ano', 'id_municipio']).agg('sum').reset_index(), how = 'left', left_on = ['ano', 'id_municipio'], right_on = ['ano', 'id_municipio'])

# %%
keep2 = pd.merge(keep, df[['id_candidato_bd', 'genero', 'ocupacao', 'instrucao']], how = 'left', left_on = ['id_candidato_bd', 'ano'], right_on = ['id_candidato_bd', 'ano'])

# %%
keep.to_csv('election_munic.csv')

# %%
#

# %%
missing_df = pd.DataFrame(missing_incumbant, columns = ['index', 'ano', 'id_candidato_bd'])

# %%
votes_missing_df = pd.DataFrame(missing, columns = ['index', 'ano', 'id_candidato_bd'])

# %%
keep.head()
# Out:
#     ano id_municipio id_candidato_bd sigla_partido  votos_winner  votos  \
# 0  2000      2708907         1265591           PSD          3147   4882
# 1  2000      1302553           19147           PST          1455   5658
# 2  2000      1302553           19147           PST          1455   5658
# 3  2000      2903300         1071793           PAN          2135   3598
# 4  2000      2903300         1071793           PAN          2135   3598
#
#    incumbant_run  incumbant_win  term_lim_seat  margin  votos_pct     genero  \
# 0            0.0            0.0            0.0  1412.0   0.644613  masculino
# 1            0.0            0.0            0.0   155.0   0.257158  masculino
# 2            0.0            0.0            0.0   155.0   0.257158  masculino
# 3            0.0            0.0            0.0   708.0   0.593385  masculino
# 4            0.0            0.0            0.0   708.0   0.593385  masculino
#
#                                     ocupacao                 instrucao
# 0  proprietario de estabelecimento comercial     ensino medio completo
# 1                                     medico  ensino superior completo
# 2                                     medico  ensino superior completo
# 3                                     outros  ensino superior completo
# 4       aposentado (exceto servidor publico)  ensino superior completo

# %%
vote[]
# Out:
#     ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 0  1996      1  eleicao ordinaria       AL      2704302            27855
# 1  1996      1  eleicao ordinaria       AM      1302603             2550
# 2  1996      1  eleicao ordinaria       BA      2927408            38490
# 3  1996      1  eleicao ordinaria       BA      2927408            38490
# 4  1996      1  eleicao ordinaria       BA      2927408            38490
#
#       cargo sigla_partido numero_candidato sequencial_candidato  \
# 0  prefeito           PSD               41                  NaN
# 1  prefeito          PSTU               16                  NaN
# 2  prefeito           PAN               26                  NaN
# 3  prefeito           PCO               29                  NaN
# 4  prefeito           PGT               30                  NaN
#
#   id_candidato_bd   resultado  votos
# 0             NaN  nao eleito   2388
# 1             NaN  nao eleito   1713
# 2             NaN  nao eleito  15721
# 3             NaN  nao eleito    705
# 4             NaN  nao eleito    989

# %%
vote_missing
# Out:
# []
