# %%
import pandas as pd
from unidecode import unidecode
import numpy as np

# %%
convert_muni = pd.read_csv('https://raw.githubusercontent.com/ekatovich/Municipality_Name_ID_crosswalk/master/Raw_Brazil_GeographicalUnits.csv', encoding='latin-1')
convert_muni = convert_muni[['uf', 'uf_name', 'mesoregion_stub', 'mesoregion_name',
       'microregion_stub', 'microregion_name', 'munic_stub', 'munic_code',
       'munic_name']]
convert_muni.munic_code = convert_muni.munic_code.astype(str)
convert_muni.munic_name = convert_muni.munic_name.apply(unidecode).apply(lambda x: x.lower())
convert_muni.munic_name = convert_muni.munic_name.apply(lambda x: x.replace('\'', '').replace(' ', ''))
convert_muni.head()
# Out:
#    uf   uf_name  mesoregion_stub    mesoregion_name  microregion_stub  \
# 0  11  Rondônia                2  Leste Rondoniense                 6
# 1  11  Rondônia                2  Leste Rondoniense                 6
# 2  11  Rondônia                2  Leste Rondoniense                 3
# 3  11  Rondônia                2  Leste Rondoniense                 5
# 4  11  Rondônia                2  Leste Rondoniense                 3
#
#    microregion_name  munic_stub munic_code            munic_name
# 0            Cacoal          15    1100015    altaflorestadoeste
# 1            Cacoal         379    1100379  altoalegredosparecis
# 2         Ariquemes         403    1100403           altoparaiso
# 3  Alvorada D'Oeste         346    1100346        alvoradadoeste
# 4         Ariquemes          23    1100023             ariquemes

# %%
#these are the ones in convert
original_wrong = ['alvoradadoeste', 'assu', 'januariocicco', 'camacan',
       'eldoradodocarajas', 'espigaodoeste', 'grachocardoso',
       'graopara', 'olhos-dagua', 'quijingue', 'santaizabeldopara',
       'saoluizdoparaitinga', 'sem-peixe', 'assu', 'ibiassuce', 'assuncaodopiaui']

#there are the ones in df that we want to put in convert
replace = ['alvoradadooeste', 'acu', 'boasaude', 'camaca',
       'eldoradodoscarajas', 'espigaodooeste', 'gracchocardoso',
       'grao-para', 'olhosdagua', 'quinjingue', 'santaisabeldopara',
       'saoluisdoparaitinga', 'sempeixe', 'acu', 'ibiassuce', 'assuncaodopiaui']

# %%
for i in range(len(original_wrong)):
    old = original_wrong[i]
    new = replace[i]
    convert_muni = convert_muni.replace({old: new}, regex=True)

# %%
cols = ['ANO_ELEICAO', 'NR_TURNO', 'NM_TIPO_ELEICAO', 'SG_UF', 'CD_MUNICIPIO', 'DS_CARGO', 'SQ_CANDIDATO', 'NR_CANDIDATO', 'NM_UE', 'DS_SIT_TOT_TURNO', 'QT_VOTOS_NOMINAIS', 'SG_PARTIDO']

# %%
       'conquista d oeste', 'diamante d oeste', 'dias d avila',
       'eldorado dos carajas', 'espigao do oeste', 'estrela d oeste',
       'figueiropolis d oeste', 'gloria d oeste', 'graccho cardoso',
       'grao-para', 'guarani d oeste', 'herval d oeste',
       'itapejara d oeste', 'itaporanga d ajuda', 'lagoa d anta',
       'lambari d oeste', 'machadinho d oeste', 'mae d agua',
       'mirassol d oeste', 'nova brasilandia d oeste', 'olho d agua',
       'olho d agua das cunhas', 'olho d agua das flores',
       'olho d agua do borges', 'olho d agua do casado',
       'olho d agua do piaui', 'olho d agua grande', 'olhos d agua',
       'palmeira d oeste', 'pau d arco', 'pau d arco do piaui',
       'perola d oeste', 'pingo d agua', 'quinjingue',
       'rancho alegre d oeste', 'sant ana do livramento',
       'santa barbara d oeste', 'santa clara d oeste',
       'santa isabel do para', 'santa luzia d oeste',
       'santa rita d oeste', 'sao felipe d oeste', 'sao joao d alianca',
       'sao joao do pau d alho', 'sao jorge d oeste',
       'sao luis do paraitinga', 'sem peixe', 'sitio d abadia',
       'tanque d arca'
# Out:
# 'tanque d arca'

# %%
df = pd.read_csv('/Users/annieulichney/Downloads/votacao_candidato_munzona_2016-2/votacao_candidato_munzona_2016_BRASIL.csv',  delimiter=';', encoding='latin1')
df = df[cols]

#df.loc[df[df.NM_UE == 'olho d agua das flores'].index, 'NM_UE'] = 'olho d\'agua das flores'
#df.loc[df[df.NM_UE == 'alta floresta d oeste'].index, 'NM_UE'] = 'alta floresta d\'oeste'
#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] = 'alvorada d\'oeste'
#df.loc[df[df.NM_UE == 'aparecida d oeste'].index, 'NM_UE'] = 'aparecida d\'oeste'
#df.loc[df[df.NM_UE == 'assu'].index, 'NM_UE'] = 'acu'
#df.loc[df[df.NM_UE == 'barra d alcantara'].index, 'NM_UE'] = 'barra d\'alcantara'
#df.loc[df[df.NM_UE == 'boa saude'].index, 'NM_UE'] = 'januario cicco'
#df.loc[df[df.NM_UE == 'camaca'].index, 'NM_UE'] = 'camacan'

#df.loc[df[df.NM_UE == 'conquista d oeste'].index, 'NM_UE'] = 'conquista d\' oeste'
#df.loc[df[df.NM_UE == 'diamante d oeste'].index, 'NM_UE'] = 'diamante d\' oeste'
#df.loc[df[df.NM_UE == 'dias d avila'].index, 'NM_UE'] = 'dias d\' avila'

#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] =
#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] =
#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] =
#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] =
#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] =
#df.loc[df[df.NM_UE == 'alvorada do oeste'].index, 'NM_UE'] =

# %%
df.NM_TIPO_ELEICAO = df.NM_TIPO_ELEICAO.apply(unidecode).apply(lambda x: x.lower())
df.DS_CARGO = df.DS_CARGO.apply(unidecode).apply(lambda x: x.lower())
df.NM_UE = df.NM_UE.apply(unidecode).apply(lambda x: x.lower())
df.DS_SIT_TOT_TURNO = df.DS_SIT_TOT_TURNO.apply(unidecode).apply(lambda x: x.lower())
df.NM_UE = df.NM_UE.apply(lambda x: x.replace('\'', '').replace(' ', ''))

# %%
convert_muni.head()
# Out:
#    uf   uf_name  mesoregion_stub    mesoregion_name  microregion_stub  \
# 0  11  Rondônia                2  Leste Rondoniense                 6
# 1  11  Rondônia                2  Leste Rondoniense                 6
# 2  11  Rondônia                2  Leste Rondoniense                 3
# 3  11  Rondônia                2  Leste Rondoniense                 5
# 4  11  Rondônia                2  Leste Rondoniense                 3
#
#    microregion_name  munic_stub munic_code            munic_name
# 0            Cacoal          15    1100015    altaflorestadoeste
# 1            Cacoal         379    1100379  altoalegredosparecis
# 2         Ariquemes         403    1100403           altoparaiso
# 3  Alvorada D'Oeste         346    1100346       alvoradadooeste
# 4         Ariquemes          23    1100023             ariquemes

# %%
df = pd.merge(df, convert_muni[['munic_name', 'munic_code']], how = 'left', left_on = ['NM_UE'], right_on = ['munic_name'])

# %%
df
# Out:
#          ANO_ELEICAO  NR_TURNO    NM_TIPO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 0               2016         1  eleicao ordinaria    AC          1120
# 1               2016         1  eleicao ordinaria    AC          1120
# 2               2016         1  eleicao ordinaria    AC          1120
# 3               2016         1  eleicao ordinaria    AC          1120
# 4               2016         1  eleicao ordinaria    AC          1120
# ...              ...       ...                ...   ...           ...
# 1025507         2016         2  eleicao ordinaria    SP         70750
# 1025508         2016         2  eleicao ordinaria    SP         70750
# 1025509         2016         2  eleicao ordinaria    SP         70750
# 1025510         2016         2  eleicao ordinaria    SP         70750
# 1025511         2016         2  eleicao ordinaria    SP         70750
#
#          DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO               NM_UE  \
# 0        prefeito   10000002509            45          acrelandia
# 1        prefeito   10000002445            40          acrelandia
# 2        prefeito   10000001075            11          acrelandia
# 3        prefeito   10000002100            10          acrelandia
# 4        prefeito   10000001284            12          acrelandia
# ...           ...           ...           ...                 ...
# 1025507  prefeito  250000010056            45  saobernardodocampo
# 1025508  prefeito  250000013230            23  saobernardodocampo
# 1025509  prefeito  250000010056            45  saobernardodocampo
# 1025510  prefeito  250000013230            23  saobernardodocampo
# 1025511  prefeito  250000010056            45  saobernardodocampo
#
#         DS_SIT_TOT_TURNO  QT_VOTOS_NOMINAIS SG_PARTIDO          munic_name  \
# 0             nao eleito                627       PSDB          acrelandia
# 1                 eleito               3852        PSB          acrelandia
# 2             nao eleito               1545         PP          acrelandia
# 3             nao eleito                259        PRB          acrelandia
# 4             nao eleito                886        PDT          acrelandia
# ...                  ...                ...        ...                 ...
# 1025507           eleito              34691       PSDB  saobernardodocampo
# 1025508       nao eleito              34438        PPS  saobernardodocampo
# 1025509           eleito              42241       PSDB  saobernardodocampo
# 1025510       nao eleito              17126        PPS  saobernardodocampo
# 1025511           eleito              30476       PSDB  saobernardodocampo
#
#         munic_code
# 0          1200013
# 1          1200013
# 2          1200013
# 3          1200013
# 4          1200013
# ...            ...
# 1025507    3548708
# 1025508    3548708
# 1025509    3548708
# 1025510    3548708
# 1025511    3548708
#
# [1025512 rows x 14 columns]

# %%
df['id_municipio_tse'] = np.nan
df['id_candidato_bd'] = np.nan

#df['sigla_partido'] = np.nan

# %%
df.head()
# Out:
#    ANO_ELEICAO  NR_TURNO    NM_TIPO_ELEICAO SG_UF  CD_MUNICIPIO  DS_CARGO  \
# 0         2016         1  eleicao ordinaria    AC          1120  prefeito
# 1         2016         1  eleicao ordinaria    AC          1120  prefeito
# 2         2016         1  eleicao ordinaria    AC          1120  prefeito
# 3         2016         1  eleicao ordinaria    AC          1120  prefeito
# 4         2016         1  eleicao ordinaria    AC          1120  prefeito
#
#    SQ_CANDIDATO  NR_CANDIDATO       NM_UE DS_SIT_TOT_TURNO  QT_VOTOS_NOMINAIS  \
# 0   10000002509            45  acrelandia       nao eleito                627
# 1   10000002445            40  acrelandia           eleito               3852
# 2   10000001075            11  acrelandia       nao eleito               1545
# 3   10000002100            10  acrelandia       nao eleito                259
# 4   10000001284            12  acrelandia       nao eleito                886
#
#   SG_PARTIDO  munic_name munic_code  id_municipio_tse  id_candidato_bd
# 0       PSDB  acrelandia    1200013               NaN              NaN
# 1        PSB  acrelandia    1200013               NaN              NaN
# 2         PP  acrelandia    1200013               NaN              NaN
# 3        PRB  acrelandia    1200013               NaN              NaN
# 4        PDT  acrelandia    1200013               NaN              NaN

# %%
['ano', 'turno', 'tipo_eleicao', 'sigla_uf', 'id_municipio',
       'id_municipio_tse', 'cargo', 'sigla_partido', 'numero_candidato',
       'sequencial_candidato', 'id_candidato_bd', 'resultado', 'votos']
# Out:
# ['ano',
#  'turno',
#  'tipo_eleicao',
#  'sigla_uf',
#  'id_municipio',
#  'id_municipio_tse',
#  'cargo',
#  'sigla_partido',
#  'numero_candidato',
#  'sequencial_candidato',
#  'id_candidato_bd',
#  'resultado',
#  'votos']

# %%
df.columns = ['ano', 'turno', 'tipo_eleicao', 'sigla_uf', 'id_municipio_old',
       'cargo', 'sequencial_candidato', 'numero_candidato', 'munic_name', 'resultado',
       'votos', 'sigla_partido', 'munic_name', 'id_municipio',  'id_municipio_tse', 'id_candidato_bd']

# %%
df = df.loc[:,~df.columns.duplicated()].copy()

# %%
df.head()
# Out:
#     ano  turno       tipo_eleicao sigla_uf  id_municipio_old     cargo  \
# 0  2016      1  eleicao ordinaria       AC              1120  prefeito
# 1  2016      1  eleicao ordinaria       AC              1120  prefeito
# 2  2016      1  eleicao ordinaria       AC              1120  prefeito
# 3  2016      1  eleicao ordinaria       AC              1120  prefeito
# 4  2016      1  eleicao ordinaria       AC              1120  prefeito
#
#    sequencial_candidato  numero_candidato  munic_name   resultado  votos  \
# 0           10000002509                45  acrelandia  nao eleito    627
# 1           10000002445                40  acrelandia      eleito   3852
# 2           10000001075                11  acrelandia  nao eleito   1545
# 3           10000002100                10  acrelandia  nao eleito    259
# 4           10000001284                12  acrelandia  nao eleito    886
#
#   sigla_partido id_municipio  id_municipio_tse  id_candidato_bd
# 0          PSDB      1200013               NaN              NaN
# 1           PSB      1200013               NaN              NaN
# 2            PP      1200013               NaN              NaN
# 3           PRB      1200013               NaN              NaN
# 4           PDT      1200013               NaN              NaN

# %%
np.unique(df[df.id_municipio.isna()].munic_name)
# Out:
# array(['assu', 'assuncao', 'assuncaodopiaui', 'bataguassu', 'ibiassuce',
#        'igarassu', 'pirassununga'], dtype=object)

# %%
len(np.unique(df[~df.id_municipio.astype(int, errors = 'ignore').isna()].id_municipio))
# Out:
# 5559

# %%
#np.savetxt('munic_names.txt', np.unique(convert_muni.munic_name), fmt='%s')

# %%
df = df[['ano', 'turno', 'tipo_eleicao', 'sigla_uf', 'id_municipio',
       'id_municipio_tse', 'cargo', 'sigla_partido', 'numero_candidato',
       'sequencial_candidato', 'id_candidato_bd', 'resultado', 'votos']]

# %%
df.head()
# Out:
#     ano  turno       tipo_eleicao sigla_uf id_municipio  id_municipio_tse  \
# 0  2016      1  eleicao ordinaria       AC      1200013               NaN
# 1  2016      1  eleicao ordinaria       AC      1200013               NaN
# 2  2016      1  eleicao ordinaria       AC      1200013               NaN
# 3  2016      1  eleicao ordinaria       AC      1200013               NaN
# 4  2016      1  eleicao ordinaria       AC      1200013               NaN
#
#       cargo sigla_partido  numero_candidato  sequencial_candidato  \
# 0  prefeito          PSDB                45           10000002509
# 1  prefeito           PSB                40           10000002445
# 2  prefeito            PP                11           10000001075
# 3  prefeito           PRB                10           10000002100
# 4  prefeito           PDT                12           10000001284
#
#    id_candidato_bd   resultado  votos
# 0              NaN  nao eleito    627
# 1              NaN      eleito   3852
# 2              NaN  nao eleito   1545
# 3              NaN  nao eleito    259
# 4              NaN  nao eleito    886

# %%
df.id_municipio.value_counts()
# Out:
# 3304557    148410
# 3550308     70528
# 3106200     24840
# 2927408     18980
# 1302603     16926
#             ...
# 4213153        11
# 4312179        11
# 2406908        10
# 3516408         4
# 3522307         4
# Name: id_municipio, Length: 5559, dtype: int64

# %%
df.to_csv('election_results_2016.csv', index = False)

# %%
df
