# %%
import pandas as pd
import pyreadr
import numpy as np
from tqdm import tqdm

# %%
path = '/Users/annieulichney/Library/CloudStorage/Box-Box/Deforestation_MachineLearning/Data/cand_prefeito.Rdata'
pathvote = '/Users/annieulichney/Library/CloudStorage/Box-Box/Deforestation_MachineLearning/Data/cand_prefeito_vote.Rdata'

df = pyreadr.read_r(path)['cand']
vote = pyreadr.read_r(pathvote)['cand']
# Out:
# ---------------------------------------------------------------------------
# LibrdataError                             Traceback (most recent call last)
# <ipython-input-2-3849b4e3a298> in <module>
#       2 pathvote = '/Users/annieulichney/Library/CloudStorage/Box-Box/Deforestation_MachineLearning/Data/cand_prefeito_vote.Rdata'
#       3
# ----> 4 df = pyreadr.read_r(path)['cand']
#       5 vote = pyreadr.read_r(pathvote)['cand']
#       6
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyreadr/pyreadr.py in read_r(path, use_objects, timezone)
#      64     if not os.path.isfile(filename_bytes):
#      65         raise PyreadrError("File {0} does not exist!".format(filename_bytes))
# ---> 66     parser.parse(filename_bytes)
#      67
#      68     result = OrderedDict()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyreadr/librdata.pyx in pyreadr.librdata.Parser.parse()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyreadr/librdata.pyx in pyreadr.librdata.Parser.parse()
#
# LibrdataError: Unable to read from file

# %%
print(df.shape)
print(vote.shape)
# Out:
# (100307, 27)
# (96838, 13)

# %%
df.head()
# Out:
#     ano       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 0  1996  eleicao ordinaria       PI      2211001            12190
# 1  1996  eleicao ordinaria       SE      2800308            31054
# 2  1996  eleicao ordinaria       RS      4314902            88013
# 3  1996  eleicao ordinaria       MG      3106200            41238
# 4  1996  eleicao ordinaria       PB      2507507            20516
#
#   id_candidato_bd  cpf titulo_eleitoral sequencial numero  ...  \
# 0             NaN  NaN              NaN        NaN     16  ...
# 1             NaN  NaN              NaN        NaN     16  ...
# 2             NaN  NaN              NaN        NaN     56  ...
# 3             NaN  NaN              NaN        NaN     16  ...
# 4             NaN  NaN              NaN        NaN     16  ...
#
#   data_nascimento idade genero instrucao estado_civil nacionalidade  \
# 0      1966-11-18    30    NaN       NaN          NaN           NaN
# 1      1956-05-23    40    NaN       NaN          NaN           NaN
# 2      1950-07-12    46    NaN       NaN          NaN           NaN
# 3      1953-06-07    43    NaN       NaN          NaN           NaN
# 4      1953-04-04    43    NaN       NaN          NaN           NaN
#
#   sigla_uf_nascimento municipio_nascimento email raca
# 0                 NaN                  NaN   NaN  NaN
# 1                 NaN                  NaN   NaN  NaN
# 2                 NaN                  NaN   NaN  NaN
# 3                 NaN                  NaN   NaN  NaN
# 4                 NaN                  NaN   NaN  NaN
#
# [5 rows x 27 columns]

# %%
vote.head()
# Out:
#     ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 0  1996      1  eleicao ordinaria       AL      2704302            27855
# 1  1996      1  eleicao ordinaria       AM      1302603             2550
# 2  1996      1  eleicao ordinaria       BA      2927408            38490
# 3  1996      1  eleicao ordinaria       BA      2927408            38490
# 4  1996      1  eleicao ordinaria       BA      2927408            38490
#
#       cargo sigla_partido numero_candidato sequencial_candidato  \
# 0  prefeito           PSD               41                  NaN
# 1  prefeito          PSTU               16                  NaN
# 2  prefeito           PAN               26                  NaN
# 3  prefeito           PCO               29                  NaN
# 4  prefeito           PGT               30                  NaN
#
#   id_candidato_bd   resultado  votos
# 0             NaN  nao eleito   2388
# 1             NaN  nao eleito   1713
# 2             NaN  nao eleito  15721
# 3             NaN  nao eleito    705
# 4             NaN  nao eleito    989

# %%
combos = list(zip(vote.groupby(['ano','id_municipio']).size().reset_index().rename(columns={0:'count'}).ano, vote.groupby(['ano','id_municipio']).size().reset_index().rename(columns={0:'count'}).id_municipio))

# %%
for c in combos[0:10]:
    this_year = c[0]
    this_mun = c[1]
